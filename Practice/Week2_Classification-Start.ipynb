# %% [markdown]
# # Iris Classification using Logistic Regression and Random Forest
#
# This notebook demonstrates classification techniques using the Iris dataset, implementing both Logistic Regression and Random Forest models.

# %% [markdown]
# ## 1. Data Loading and Initial Setup
#
# First, let's import the required libraries and load the Iris dataset.
# * Import necessary libraries (matplotlib, pandas, sklearn)
# * Load the Iris dataset
# * Create a DataFrame with features and target

# %%
# TODO: Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import seaborn as sns

# %%
# TODO: Load Iris dataset and create DataFrame
iris= load_iris()
print(iris.DESCR) 
df = load_iris(as_frame=True).frame
print(df.head())
print(df.info())
print(df.shape)

# 2 ways to map- when need static and direct then use dictionary mapping
# when need dynamic mapping, mapping on the fly, then use lambda function
#df['target_name'] = df['target'].map({i: name for i, name in enumerate(load_iris().target_names)})
df['target_name'] = df['target'].map(lambda x: load_iris().target_names[x])
df.head()
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)
#
# Perform initial data analysis:
# * Calculate basic statistics
# * Examine class distribution
# * Look for any patterns or anomalies

# %%
# TODO: Display numeric statistics
print(df.describe().T)


# TODO: Display class distribution and proportions
print(df.x)
# Out:
#                    count      mean       std  min  25%   50%  75%  max
# sepal length (cm)  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal width (cm)   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal length (cm)  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal width (cm)   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5
# target             150.0  1.000000  0.819232  0.0  0.0  1.00  2.0  2.0

# %% [markdown]
# ## 3. Data Visualization
#
# Create visualizations to understand:
# * Feature relationships (using pairplot)
# * Feature correlations (using heatmap)

# %%
# TODO: Create pairplot using seaborn
#sns.pairplot(df, vars=iris.feature_names, hue='target_name')
sns.pairplot(df, vars=df.columns[: -2], hue='target_name')

# %%
# TODO: Create correlation heatmap

# %% [markdown]
# ## 4. Feature Engineering and PCA
#
# Perform PCA to:
# * Reduce dimensionality
# * Visualize data in 2D
# * Examine explained variance ratio

# %%
# TODO: Implement PCA
# 1. Prepare data
# 2. Scale features
# 3. Apply PCA
# 4. Visualize results

# %% [markdown]
# ## 5. Data Preparation and Scaling
#
# Prepare data for modeling:
# * Split into training and test sets
# * Scale features

# %%
# TODO: Split data into train and test sets

# TODO: Scale features

# %% [markdown]
# ## 6. Model Training and Evaluation
#
# Implement and evaluate two models:
# * Logistic Regression
# * Random Forest
#
# Compare their performance using accuracy scores.

# %%
# TODO: Train Logistic Regression model

# TODO: Train Random Forest model

# TODO: Make predictions and calculate accuracy

# %% [markdown]
# ## 7. Model Persistence
#
# Save the trained models for future use:
# * Save Random Forest model
# * Save Logistic Regression model
# * Save the scaler

# %%
# TODO: Save models and scaler to disk
